# %%
print("Welcome to Data Science")
# Out:
# Welcome to Data Science

# %%
x=5
print(x)
print("Value of x is :" , x)
print(type(x))
# Out:
# 5
# Value of x is : 5
# <class 'int'>

# %%
y=6
print(y)
print("Value of y :" , y)
print(type(y))
# Out:
# 6
# Value of y : 6
# <class 'int'>
